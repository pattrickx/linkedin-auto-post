# %%
! pip install -r requirements.txt

# %%
from extractor import process_frontpages
from datetime import date

articles = await process_frontpages(
    frontpage_urls=["https://www.anthropic.com/engineering"],
    date_from=date(2025, 5, 15),
    date_to=date(2027, 5, 20),
    model="gpt-4o-mini",   # ou "gpt-4o" para mais precisão
    progress_callback=print,
)
# Out:
# 📥 Buscando frontpage: www.anthropic.com
# 🤖 Extraindo artigos com OpenAI (gpt-4o-mini): www.anthropic.com
# ✅ www.anthropic.com: 24 artigos encontrados, 19 no intervalo de datas
#
# 🕷️ Extraindo conteúdo de 19 artigos...
#   ↳ An update on recent Claude Code quality reports...
#   ↳ Scaling Managed Agents: Decoupling the brain from the hands...
#   ↳ Claude Code auto mode: a safer way to skip permissions...
#   ↳ Harness design for long-running application development...
#   ↳ Eval awareness in Claude Opus 4.6’s BrowseComp performance...
#   ↳ Quantifying infrastructure noise in agentic coding evals...
#   ↳ Building a C compiler with a team of parallel Claudes...
#   ↳ Designing AI-resistant technical evaluations...
#   ↳ Demystifying evals for AI agents...
#   ↳ Effective harnesses for long-running agents...
#   ↳ Introducing advanced tool use on the Claude Developer Platfo...
#   ↳ Code execution with MCP: Building more efficient agents...
# ...

# %%
articles
# Out:
# [Article(title='An update on recent Claude Code quality reports', url='https://www.anthropic.com/engineering/april-23-postmortem', date='2026-04-23', source='www.anthropic.com', content_md='[Erro: ]'),
#  Article(title='Scaling Managed Agents: Decoupling the brain from the hands', url='https://www.anthropic.com/engineering/managed-agents', date='2026-04-08', source='www.anthropic.com', content_md='[Erro: ]'),
#  Article(title='Claude Code auto mode: a safer way to skip permissions', url='https://www.anthropic.com/engineering/claude-code-auto-mode', date='2026-03-25', source='www.anthropic.com', content_md='[Erro: ]'),
#  Article(title='Harness design for long-running application development', url='https://www.anthropic.com/engineering/harness-design-long-running-apps', date='2026-03-24', source='www.anthropic.com', content_md='[Erro: ]'),
# ...

# %%
https://www.anthropic.com/engineering
https://engineering.fb.com
https://devblogs.microsoft.com
https://netflixtechblog.com
https://www.uber.com/blog/engineering
https://engineering.atspotify.com
https://slack.engineering
https://aws.amazon.com/blogs/architecture
https://blog.cloudflare.com
https://github.blog/engineering
https://about.gitlab.com/blog
https://stripe.com/blog/engineering
https://medium.com/paypal-tech
https://newsletter.pragmaticengineer.com
https://blog.bytebytego.com
https://tldr.tech
https://news.ycombinator.com
https://openai.com/research
https://huggingface.co/blog
https://deepmind.google/discover/blog
https://wandb.ai/fully-connected
